# %% [markdown]
# <a href="https://colab.research.google.com/github/Isini-Umanda/Titanic/blob/main/Taitanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4cbc8b98-3b0d-4491-8b3c-db8ce068e03a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cbc8b98-3b0d-4491-8b3c-db8ce068e03a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Fare','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0

# %%
inputs=df.drop('Survived',axis='columns')
target=df.Survived
inputs
# Out:
#      Pclass     Sex   Age
# 0         3    male  22.0
# 1         1  female  38.0
# 2         3  female  26.0
# 3         1  female  35.0
# 4         3    male  35.0
# ..      ...     ...   ...
# 886       2    male  27.0
# 887       1  female  19.0
# 888       3  female   NaN
# 889       1    male  26.0
# 890       3    male  32.0
#
# [891 rows x 3 columns]

# %%
dummies=pd.get_dummies(inputs.Sex)
dummies.head(30)
# Out:
#     female  male
# 0        0     1
# 1        1     0
# 2        1     0
# 3        1     0
# 4        0     1
# 5        0     1
# 6        0     1
# 7        0     1
# 8        1     0
# 9        1     0
# 10       1     0
# 11       1     0
# 12       0     1
# 13       0     1
# 14       1     0
# 15       1     0
# 16       0     1
# 17       0     1
# 18       1     0
# 19       1     0
# 20       0     1
# 21       0     1
# 22       1     0
# 23       0     1
# 24       1     0
# 25       1     0
# 26       0     1
# 27       0     1
# 28       1     0
# 29       0     1

# %%
inputs=pd.concat([inputs,dummies],axis='columns')
inputs.head(5)
# Out:
#    Pclass     Sex   Age  female  male
# 0       3    male  22.0       0     1
# 1       1  female  38.0       1     0
# 2       3  female  26.0       1     0
# 3       1  female  35.0       1     0
# 4       3    male  35.0       0     1

# %%
inputs.drop(['Sex','male'],axis='columns',inplace=True)
inputs.head(10)
# Out:
#    Pclass   Age  female
# 0       3  22.0       0
# 1       1  38.0       1
# 2       3  26.0       1
# 3       1  35.0       1
# 4       3  35.0       0
# 5       3   NaN       0
# 6       1  54.0       0
# 7       3   2.0       0
# 8       3  27.0       1
# 9       2  14.0       1

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs['Age']=df['Age'].fillna(df['Age'].median())

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(inputs,target,test_size=0.3)

# %%
X_train
# Out:
#      Pclass   Age  female
# 770       3  24.0       0
# 195       1  58.0       1
# 445       1   4.0       0
# 30        1  40.0       0
# 236       2  44.0       0
# ..      ...   ...     ...
# 764       3  16.0       0
# 397       2  46.0       0
# 56        2  21.0       1
# 522       3  28.0       0
# 46        3  28.0       0
#
# [623 rows x 3 columns]

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.753731343283582

# %%
X_test[0:10]
# Out:
#      Pclass   Age  female
# 530       2   2.0       1
# 417       2  18.0       1
# 144       2  18.0       0
# 662       1  47.0       0
# 355       3  28.0       0
# 508       3  28.0       0
# 839       1  28.0       0
# 258       1  35.0       1
# 888       3  28.0       1
# 196       3  28.0       0

# %%
y_test[0:10]
# Out:
# 530    1
# 417    1
# 144    0
# 662    0
# 355    0
# 508    0
# 839    1
# 258    1
# 888    0
# 196    0
# Name: Survived, dtype: int64

# %%
model.predict(X_test[0:10])
# Out:
# array([1, 1, 0, 0, 0, 0, 0, 1, 1, 0])
